# %%
import numpy as np
from skimage import io, transform
from pathlib import Path
from skimage.filters import threshold_local
import imageio

# ---------------------------------------------------
# CONFIG
# ---------------------------------------------------
jpg_folder = Path(r"D:\DMMMSU\Thesis2025\another 3D\testset\test\tomo_003acc")     # <-- CHANGE THIS
png_folder = Path("converted_png1")            # output folder
png_folder.mkdir(exist_ok=True)

resize_shape = (200, 200)

mask_method = "superclean"   # adaptive | percentile | manual | superclean
manual_threshold_value = 0.3
percentile_value = 20
# ---------------------------------------------------

# %%
# PART 1 — Convert JPG → PNG
# ---------------------------------------------------
jpg_files = sorted(jpg_folder.glob("*.jpg"))
print("Found JPG files:", len(jpg_files))

if len(jpg_files) == 0:
    raise ValueError("❌ No .jpg files found. Check folder path!")

for f in jpg_files:
    img = io.imread(f)
    png_path = png_folder / (f.stem + ".png")
    imageio.imwrite(png_path, img)
    print("Converted:", f.name, "→", png_path.name)

print("\n✔ JPG → PNG conversion complete.\n")
# Out:
# Found JPG files: 500
# Converted: slice_0000.jpg → slice_0000.png
# Converted: slice_0001.jpg → slice_0001.png
# Converted: slice_0002.jpg → slice_0002.png
# Converted: slice_0003.jpg → slice_0003.png
# Converted: slice_0004.jpg → slice_0004.png
# Converted: slice_0005.jpg → slice_0005.png
# Converted: slice_0006.jpg → slice_0006.png
# Converted: slice_0007.jpg → slice_0007.png
# Converted: slice_0008.jpg → slice_0008.png
# Converted: slice_0009.jpg → slice_0009.png
# Converted: slice_0010.jpg → slice_0010.png
# Converted: slice_0011.jpg → slice_0011.png
# Converted: slice_0012.jpg → slice_0012.png
# Converted: slice_0013.jpg → slice_0013.png
# Converted: slice_0014.jpg → slice_0014.png
# Converted: slice_0015.jpg → slice_0015.png
# Converted: slice_0016.jpg → slice_0016.png
# Converted: slice_0017.jpg → slice_0017.png
# Converted: slice_0018.jpg → slice_0018.png
# Converted: slice_0019.jpg → slice_0019.png
# Converted: slice_0020.jpg → slice_0020.png
# Converted: slice_0021.jpg → slice_0021.png
# Converted: slice_0022.jpg → slice_0022.png
# Converted: slice_0023.jpg → slice_0023.png
# Converted: slice_0024.jpg → slice_0024.png
# Converted: slice_0025.jpg → slice_0025.png
# Converted: slice_0026.jpg → slice_0026.png
# Converted: slice_0027.jpg → slice_0027.png
# Converted: slice_0028.jpg → slice_0028.png
# Converted: slice_0029.jpg → slice_0029.png
# Converted: slice_0030.jpg → slice_0030.png
# Converted: slice_0031.jpg → slice_0031.png
# Converted: slice_0032.jpg → slice_0032.png
# Converted: slice_0033.jpg → slice_0033.png
# Converted: slice_0034.jpg → slice_0034.png
# Converted: slice_0035.jpg → slice_0035.png
# Converted: slice_0036.jpg → slice_0036.png
# Converted: slice_0037.jpg → slice_0037.png
# Converted: slice_0038.jpg → slice_0038.png
# Converted: slice_0039.jpg → slice_0039.png
# Converted: slice_0040.jpg → slice_0040.png
# Converted: slice_0041.jpg → slice_0041.png
# Converted: slice_0042.jpg → slice_0042.png
# Converted: slice_0043.jpg → slice_0043.png
# Converted: slice_0044.jpg → slice_0044.png
# Converted: slice_0045.jpg → slice_0045.png
# Converted: slice_0046.jpg → slice_0046.png
# Converted: slice_0047.jpg → slice_0047.png
# Converted: slice_0048.jpg → slice_0048.png
# Converted: slice_0049.jpg → slice_0049.png
# Converted: slice_0050.jpg → slice_0050.png
# Converted: slice_0051.jpg → slice_0051.png
# Converted: slice_0052.jpg → slice_0052.png
# Converted: slice_0053.jpg → slice_0053.png
# Converted: slice_0054.jpg → slice_0054.png
# Converted: slice_0055.jpg → slice_0055.png
# Converted: slice_0056.jpg → slice_0056.png
# Converted: slice_0057.jpg → slice_0057.png
# Converted: slice_0058.jpg → slice_0058.png
# Converted: slice_0059.jpg → slice_0059.png
# Converted: slice_0060.jpg → slice_0060.png
# Converted: slice_0061.jpg → slice_0061.png
# Converted: slice_0062.jpg → slice_0062.png
# Converted: slice_0063.jpg → slice_0063.png
# Converted: slice_0064.jpg → slice_0064.png
# Converted: slice_0065.jpg → slice_0065.png
# Converted: slice_0066.jpg → slice_0066.png
# Converted: slice_0067.jpg → slice_0067.png
# Converted: slice_0068.jpg → slice_0068.png
# Converted: slice_0069.jpg → slice_0069.png
# Converted: slice_0070.jpg → slice_0070.png
# Converted: slice_0071.jpg → slice_0071.png
# Converted: slice_0072.jpg → slice_0072.png
# Converted: slice_0073.jpg → slice_0073.png
# Converted: slice_0074.jpg → slice_0074.png
# Converted: slice_0075.jpg → slice_0075.png
# Converted: slice_0076.jpg → slice_0076.png
# Converted: slice_0077.jpg → slice_0077.png
# Converted: slice_0078.jpg → slice_0078.png
# Converted: slice_0079.jpg → slice_0079.png
# Converted: slice_0080.jpg → slice_0080.png
# Converted: slice_0081.jpg → slice_0081.png
# Converted: slice_0082.jpg → slice_0082.png
# Converted: slice_0083.jpg → slice_0083.png
# Converted: slice_0084.jpg → slice_0084.png
# Converted: slice_0085.jpg → slice_0085.png
# Converted: slice_0086.jpg → slice_0086.png
# Converted: slice_0087.jpg → slice_0087.png
# Converted: slice_0088.jpg → slice_0088.png
# Converted: slice_0089.jpg → slice_0089.png
# Converted: slice_0090.jpg → slice_0090.png
# Converted: slice_0091.jpg → slice_0091.png
# Converted: slice_0092.jpg → slice_0092.png
# Converted: slice_0093.jpg → slice_0093.png
# Converted: slice_0094.jpg → slice_0094.png
# Converted: slice_0095.jpg → slice_0095.png
# Converted: slice_0096.jpg → slice_0096.png
# Converted: slice_0097.jpg → slice_0097.png
# Converted: slice_0098.jpg → slice_0098.png
# Converted: slice_0099.jpg → slice_0099.png
# Converted: slice_0100.jpg → slice_0100.png
# Converted: slice_0101.jpg → slice_0101.png
# Converted: slice_0102.jpg → slice_0102.png
# Converted: slice_0103.jpg → slice_0103.png
# Converted: slice_0104.jpg → slice_0104.png
# Converted: slice_0105.jpg → slice_0105.png
# Converted: slice_0106.jpg → slice_0106.png
# Converted: slice_0107.jpg → slice_0107.png
# Converted: slice_0108.jpg → slice_0108.png
# Converted: slice_0109.jpg → slice_0109.png
# Converted: slice_0110.jpg → slice_0110.png
# Converted: slice_0111.jpg → slice_0111.png
# Converted: slice_0112.jpg → slice_0112.png
# Converted: slice_0113.jpg → slice_0113.png
# Converted: slice_0114.jpg → slice_0114.png
# Converted: slice_0115.jpg → slice_0115.png
# Converted: slice_0116.jpg → slice_0116.png
# Converted: slice_0117.jpg → slice_0117.png
# Converted: slice_0118.jpg → slice_0118.png
# Converted: slice_0119.jpg → slice_0119.png
# Converted: slice_0120.jpg → slice_0120.png
# Converted: slice_0121.jpg → slice_0121.png
# Converted: slice_0122.jpg → slice_0122.png
# Converted: slice_0123.jpg → slice_0123.png
# Converted: slice_0124.jpg → slice_0124.png
# Converted: slice_0125.jpg → slice_0125.png
# Converted: slice_0126.jpg → slice_0126.png
# Converted: slice_0127.jpg → slice_0127.png
# Converted: slice_0128.jpg → slice_0128.png
# Converted: slice_0129.jpg → slice_0129.png
# Converted: slice_0130.jpg → slice_0130.png
# Converted: slice_0131.jpg → slice_0131.png
# Converted: slice_0132.jpg → slice_0132.png
# Converted: slice_0133.jpg → slice_0133.png
# Converted: slice_0134.jpg → slice_0134.png
# Converted: slice_0135.jpg → slice_0135.png
# Converted: slice_0136.jpg → slice_0136.png
# Converted: slice_0137.jpg → slice_0137.png
# Converted: slice_0138.jpg → slice_0138.png
# Converted: slice_0139.jpg → slice_0139.png
# Converted: slice_0140.jpg → slice_0140.png
# Converted: slice_0141.jpg → slice_0141.png
# Converted: slice_0142.jpg → slice_0142.png
# Converted: slice_0143.jpg → slice_0143.png
# Converted: slice_0144.jpg → slice_0144.png
# Converted: slice_0145.jpg → slice_0145.png
# Converted: slice_0146.jpg → slice_0146.png
# Converted: slice_0147.jpg → slice_0147.png
# Converted: slice_0148.jpg → slice_0148.png
# Converted: slice_0149.jpg → slice_0149.png
# Converted: slice_0150.jpg → slice_0150.png
# Converted: slice_0151.jpg → slice_0151.png
# Converted: slice_0152.jpg → slice_0152.png
# Converted: slice_0153.jpg → slice_0153.png
# Converted: slice_0154.jpg → slice_0154.png
# Converted: slice_0155.jpg → slice_0155.png
# Converted: slice_0156.jpg → slice_0156.png
# Converted: slice_0157.jpg → slice_0157.png
# Converted: slice_0158.jpg → slice_0158.png
# Converted: slice_0159.jpg → slice_0159.png
# Converted: slice_0160.jpg → slice_0160.png
# Converted: slice_0161.jpg → slice_0161.png
# Converted: slice_0162.jpg → slice_0162.png
# Converted: slice_0163.jpg → slice_0163.png
# Converted: slice_0164.jpg → slice_0164.png
# Converted: slice_0165.jpg → slice_0165.png
# Converted: slice_0166.jpg → slice_0166.png
# Converted: slice_0167.jpg → slice_0167.png
# Converted: slice_0168.jpg → slice_0168.png
# Converted: slice_0169.jpg → slice_0169.png
# Converted: slice_0170.jpg → slice_0170.png
# Converted: slice_0171.jpg → slice_0171.png
# Converted: slice_0172.jpg → slice_0172.png
# Converted: slice_0173.jpg → slice_0173.png
# Converted: slice_0174.jpg → slice_0174.png
# Converted: slice_0175.jpg → slice_0175.png
# Converted: slice_0176.jpg → slice_0176.png
# Converted: slice_0177.jpg → slice_0177.png
# Converted: slice_0178.jpg → slice_0178.png
# Converted: slice_0179.jpg → slice_0179.png
# Converted: slice_0180.jpg → slice_0180.png
# Converted: slice_0181.jpg → slice_0181.png
# Converted: slice_0182.jpg → slice_0182.png
# Converted: slice_0183.jpg → slice_0183.png
# Converted: slice_0184.jpg → slice_0184.png
# Converted: slice_0185.jpg → slice_0185.png
# Converted: slice_0186.jpg → slice_0186.png
# Converted: slice_0187.jpg → slice_0187.png
# Converted: slice_0188.jpg → slice_0188.png
# Converted: slice_0189.jpg → slice_0189.png
# Converted: slice_0190.jpg → slice_0190.png
# Converted: slice_0191.jpg → slice_0191.png
# Converted: slice_0192.jpg → slice_0192.png
# Converted: slice_0193.jpg → slice_0193.png
# Converted: slice_0194.jpg → slice_0194.png
# Converted: slice_0195.jpg → slice_0195.png
# Converted: slice_0196.jpg → slice_0196.png
# Converted: slice_0197.jpg → slice_0197.png
# Converted: slice_0198.jpg → slice_0198.png
# Converted: slice_0199.jpg → slice_0199.png
# Converted: slice_0200.jpg → slice_0200.png
# Converted: slice_0201.jpg → slice_0201.png
# Converted: slice_0202.jpg → slice_0202.png
# Converted: slice_0203.jpg → slice_0203.png
# Converted: slice_0204.jpg → slice_0204.png
# Converted: slice_0205.jpg → slice_0205.png
# Converted: slice_0206.jpg → slice_0206.png
# Converted: slice_0207.jpg → slice_0207.png
# Converted: slice_0208.jpg → slice_0208.png
# Converted: slice_0209.jpg → slice_0209.png
# Converted: slice_0210.jpg → slice_0210.png
# Converted: slice_0211.jpg → slice_0211.png
# Converted: slice_0212.jpg → slice_0212.png
# Converted: slice_0213.jpg → slice_0213.png
# Converted: slice_0214.jpg → slice_0214.png
# Converted: slice_0215.jpg → slice_0215.png
# Converted: slice_0216.jpg → slice_0216.png
# Converted: slice_0217.jpg → slice_0217.png
# Converted: slice_0218.jpg → slice_0218.png
# Converted: slice_0219.jpg → slice_0219.png
# Converted: slice_0220.jpg → slice_0220.png
# Converted: slice_0221.jpg → slice_0221.png
# Converted: slice_0222.jpg → slice_0222.png
# Converted: slice_0223.jpg → slice_0223.png
# Converted: slice_0224.jpg → slice_0224.png
# Converted: slice_0225.jpg → slice_0225.png
# Converted: slice_0226.jpg → slice_0226.png
# Converted: slice_0227.jpg → slice_0227.png
# Converted: slice_0228.jpg → slice_0228.png
# Converted: slice_0229.jpg → slice_0229.png
# Converted: slice_0230.jpg → slice_0230.png
# Converted: slice_0231.jpg → slice_0231.png
# Converted: slice_0232.jpg → slice_0232.png
# Converted: slice_0233.jpg → slice_0233.png
# Converted: slice_0234.jpg → slice_0234.png
# Converted: slice_0235.jpg → slice_0235.png
# Converted: slice_0236.jpg → slice_0236.png
# Converted: slice_0237.jpg → slice_0237.png
# Converted: slice_0238.jpg → slice_0238.png
# Converted: slice_0239.jpg → slice_0239.png
# Converted: slice_0240.jpg → slice_0240.png
# Converted: slice_0241.jpg → slice_0241.png
# Converted: slice_0242.jpg → slice_0242.png
# Converted: slice_0243.jpg → slice_0243.png
# Converted: slice_0244.jpg → slice_0244.png
# Converted: slice_0245.jpg → slice_0245.png
# Converted: slice_0246.jpg → slice_0246.png
# Converted: slice_0247.jpg → slice_0247.png
# Converted: slice_0248.jpg → slice_0248.png
# Converted: slice_0249.jpg → slice_0249.png
# Converted: slice_0250.jpg → slice_0250.png
# Converted: slice_0251.jpg → slice_0251.png
# Converted: slice_0252.jpg → slice_0252.png
# Converted: slice_0253.jpg → slice_0253.png
# Converted: slice_0254.jpg → slice_0254.png
# Converted: slice_0255.jpg → slice_0255.png
# Converted: slice_0256.jpg → slice_0256.png
# Converted: slice_0257.jpg → slice_0257.png
# Converted: slice_0258.jpg → slice_0258.png
# Converted: slice_0259.jpg → slice_0259.png
# Converted: slice_0260.jpg → slice_0260.png
# Converted: slice_0261.jpg → slice_0261.png
# Converted: slice_0262.jpg → slice_0262.png
# Converted: slice_0263.jpg → slice_0263.png
# Converted: slice_0264.jpg → slice_0264.png
# Converted: slice_0265.jpg → slice_0265.png
# Converted: slice_0266.jpg → slice_0266.png
# Converted: slice_0267.jpg → slice_0267.png
# Converted: slice_0268.jpg → slice_0268.png
# Converted: slice_0269.jpg → slice_0269.png
# Converted: slice_0270.jpg → slice_0270.png
# Converted: slice_0271.jpg → slice_0271.png
# Converted: slice_0272.jpg → slice_0272.png
# Converted: slice_0273.jpg → slice_0273.png
# Converted: slice_0274.jpg → slice_0274.png
# Converted: slice_0275.jpg → slice_0275.png
# Converted: slice_0276.jpg → slice_0276.png
# Converted: slice_0277.jpg → slice_0277.png
# Converted: slice_0278.jpg → slice_0278.png
# Converted: slice_0279.jpg → slice_0279.png
# Converted: slice_0280.jpg → slice_0280.png
# Converted: slice_0281.jpg → slice_0281.png
# Converted: slice_0282.jpg → slice_0282.png
# Converted: slice_0283.jpg → slice_0283.png
# Converted: slice_0284.jpg → slice_0284.png
# Converted: slice_0285.jpg → slice_0285.png
# Converted: slice_0286.jpg → slice_0286.png
# Converted: slice_0287.jpg → slice_0287.png
# Converted: slice_0288.jpg → slice_0288.png
# Converted: slice_0289.jpg → slice_0289.png
# Converted: slice_0290.jpg → slice_0290.png
# Converted: slice_0291.jpg → slice_0291.png
# Converted: slice_0292.jpg → slice_0292.png
# Converted: slice_0293.jpg → slice_0293.png
# Converted: slice_0294.jpg → slice_0294.png
# Converted: slice_0295.jpg → slice_0295.png
# Converted: slice_0296.jpg → slice_0296.png
# Converted: slice_0297.jpg → slice_0297.png
# Converted: slice_0298.jpg → slice_0298.png
# Converted: slice_0299.jpg → slice_0299.png
# Converted: slice_0300.jpg → slice_0300.png
# Converted: slice_0301.jpg → slice_0301.png
# Converted: slice_0302.jpg → slice_0302.png
# Converted: slice_0303.jpg → slice_0303.png
# Converted: slice_0304.jpg → slice_0304.png
# Converted: slice_0305.jpg → slice_0305.png
# Converted: slice_0306.jpg → slice_0306.png
# Converted: slice_0307.jpg → slice_0307.png
# Converted: slice_0308.jpg → slice_0308.png
# Converted: slice_0309.jpg → slice_0309.png
# Converted: slice_0310.jpg → slice_0310.png
# Converted: slice_0311.jpg → slice_0311.png
# Converted: slice_0312.jpg → slice_0312.png
# Converted: slice_0313.jpg → slice_0313.png
# Converted: slice_0314.jpg → slice_0314.png
# Converted: slice_0315.jpg → slice_0315.png
# Converted: slice_0316.jpg → slice_0316.png
# Converted: slice_0317.jpg → slice_0317.png
# Converted: slice_0318.jpg → slice_0318.png
# Converted: slice_0319.jpg → slice_0319.png
# Converted: slice_0320.jpg → slice_0320.png
# Converted: slice_0321.jpg → slice_0321.png
# Converted: slice_0322.jpg → slice_0322.png
# Converted: slice_0323.jpg → slice_0323.png
# Converted: slice_0324.jpg → slice_0324.png
# Converted: slice_0325.jpg → slice_0325.png
# Converted: slice_0326.jpg → slice_0326.png
# Converted: slice_0327.jpg → slice_0327.png
# Converted: slice_0328.jpg → slice_0328.png
# Converted: slice_0329.jpg → slice_0329.png
# Converted: slice_0330.jpg → slice_0330.png
# Converted: slice_0331.jpg → slice_0331.png
# Converted: slice_0332.jpg → slice_0332.png
# Converted: slice_0333.jpg → slice_0333.png
# Converted: slice_0334.jpg → slice_0334.png
# Converted: slice_0335.jpg → slice_0335.png
# Converted: slice_0336.jpg → slice_0336.png
# Converted: slice_0337.jpg → slice_0337.png
# Converted: slice_0338.jpg → slice_0338.png
# Converted: slice_0339.jpg → slice_0339.png
# Converted: slice_0340.jpg → slice_0340.png
# Converted: slice_0341.jpg → slice_0341.png
# Converted: slice_0342.jpg → slice_0342.png
# Converted: slice_0343.jpg → slice_0343.png
# Converted: slice_0344.jpg → slice_0344.png
# Converted: slice_0345.jpg → slice_0345.png
# Converted: slice_0346.jpg → slice_0346.png
# Converted: slice_0347.jpg → slice_0347.png
# Converted: slice_0348.jpg → slice_0348.png
# Converted: slice_0349.jpg → slice_0349.png
# Converted: slice_0350.jpg → slice_0350.png
# Converted: slice_0351.jpg → slice_0351.png
# Converted: slice_0352.jpg → slice_0352.png
# Converted: slice_0353.jpg → slice_0353.png
# Converted: slice_0354.jpg → slice_0354.png
# Converted: slice_0355.jpg → slice_0355.png
# Converted: slice_0356.jpg → slice_0356.png
# Converted: slice_0357.jpg → slice_0357.png
# Converted: slice_0358.jpg → slice_0358.png
# Converted: slice_0359.jpg → slice_0359.png
# Converted: slice_0360.jpg → slice_0360.png
# Converted: slice_0361.jpg → slice_0361.png
# Converted: slice_0362.jpg → slice_0362.png
# Converted: slice_0363.jpg → slice_0363.png
# Converted: slice_0364.jpg → slice_0364.png
# Converted: slice_0365.jpg → slice_0365.png
# Converted: slice_0366.jpg → slice_0366.png
# Converted: slice_0367.jpg → slice_0367.png
# Converted: slice_0368.jpg → slice_0368.png
# Converted: slice_0369.jpg → slice_0369.png
# Converted: slice_0370.jpg → slice_0370.png
# Converted: slice_0371.jpg → slice_0371.png
# Converted: slice_0372.jpg → slice_0372.png
# Converted: slice_0373.jpg → slice_0373.png
# Converted: slice_0374.jpg → slice_0374.png
# Converted: slice_0375.jpg → slice_0375.png
# Converted: slice_0376.jpg → slice_0376.png
# Converted: slice_0377.jpg → slice_0377.png
# Converted: slice_0378.jpg → slice_0378.png
# Converted: slice_0379.jpg → slice_0379.png
# Converted: slice_0380.jpg → slice_0380.png
# Converted: slice_0381.jpg → slice_0381.png
# Converted: slice_0382.jpg → slice_0382.png
# Converted: slice_0383.jpg → slice_0383.png
# Converted: slice_0384.jpg → slice_0384.png
# Converted: slice_0385.jpg → slice_0385.png
# Converted: slice_0386.jpg → slice_0386.png
# Converted: slice_0387.jpg → slice_0387.png
# Converted: slice_0388.jpg → slice_0388.png
# Converted: slice_0389.jpg → slice_0389.png
# Converted: slice_0390.jpg → slice_0390.png
# Converted: slice_0391.jpg → slice_0391.png
# Converted: slice_0392.jpg → slice_0392.png
# Converted: slice_0393.jpg → slice_0393.png
# Converted: slice_0394.jpg → slice_0394.png
# Converted: slice_0395.jpg → slice_0395.png
# Converted: slice_0396.jpg → slice_0396.png
# Converted: slice_0397.jpg → slice_0397.png
# Converted: slice_0398.jpg → slice_0398.png
# Converted: slice_0399.jpg → slice_0399.png
# Converted: slice_0400.jpg → slice_0400.png
# Converted: slice_0401.jpg → slice_0401.png
# Converted: slice_0402.jpg → slice_0402.png
# Converted: slice_0403.jpg → slice_0403.png
# Converted: slice_0404.jpg → slice_0404.png
# Converted: slice_0405.jpg → slice_0405.png
# Converted: slice_0406.jpg → slice_0406.png
# Converted: slice_0407.jpg → slice_0407.png
# Converted: slice_0408.jpg → slice_0408.png
# Converted: slice_0409.jpg → slice_0409.png
# Converted: slice_0410.jpg → slice_0410.png
# Converted: slice_0411.jpg → slice_0411.png
# Converted: slice_0412.jpg → slice_0412.png
# Converted: slice_0413.jpg → slice_0413.png
# Converted: slice_0414.jpg → slice_0414.png
# Converted: slice_0415.jpg → slice_0415.png
# Converted: slice_0416.jpg → slice_0416.png
# Converted: slice_0417.jpg → slice_0417.png
# Converted: slice_0418.jpg → slice_0418.png
# Converted: slice_0419.jpg → slice_0419.png
# Converted: slice_0420.jpg → slice_0420.png
# Converted: slice_0421.jpg → slice_0421.png
# Converted: slice_0422.jpg → slice_0422.png
# Converted: slice_0423.jpg → slice_0423.png
# Converted: slice_0424.jpg → slice_0424.png
# Converted: slice_0425.jpg → slice_0425.png
# Converted: slice_0426.jpg → slice_0426.png
# Converted: slice_0427.jpg → slice_0427.png
# Converted: slice_0428.jpg → slice_0428.png
# Converted: slice_0429.jpg → slice_0429.png
# Converted: slice_0430.jpg → slice_0430.png
# Converted: slice_0431.jpg → slice_0431.png
# Converted: slice_0432.jpg → slice_0432.png
# Converted: slice_0433.jpg → slice_0433.png
# Converted: slice_0434.jpg → slice_0434.png
# Converted: slice_0435.jpg → slice_0435.png
# Converted: slice_0436.jpg → slice_0436.png
# Converted: slice_0437.jpg → slice_0437.png
# Converted: slice_0438.jpg → slice_0438.png
# Converted: slice_0439.jpg → slice_0439.png
# Converted: slice_0440.jpg → slice_0440.png
# Converted: slice_0441.jpg → slice_0441.png
# Converted: slice_0442.jpg → slice_0442.png
# Converted: slice_0443.jpg → slice_0443.png
# Converted: slice_0444.jpg → slice_0444.png
# Converted: slice_0445.jpg → slice_0445.png
# Converted: slice_0446.jpg → slice_0446.png
# Converted: slice_0447.jpg → slice_0447.png
# Converted: slice_0448.jpg → slice_0448.png
# Converted: slice_0449.jpg → slice_0449.png
# Converted: slice_0450.jpg → slice_0450.png
# Converted: slice_0451.jpg → slice_0451.png
# Converted: slice_0452.jpg → slice_0452.png
# Converted: slice_0453.jpg → slice_0453.png
# Converted: slice_0454.jpg → slice_0454.png
# Converted: slice_0455.jpg → slice_0455.png
# Converted: slice_0456.jpg → slice_0456.png
# Converted: slice_0457.jpg → slice_0457.png
# Converted: slice_0458.jpg → slice_0458.png
# Converted: slice_0459.jpg → slice_0459.png
# Converted: slice_0460.jpg → slice_0460.png
# Converted: slice_0461.jpg → slice_0461.png
# Converted: slice_0462.jpg → slice_0462.png
# Converted: slice_0463.jpg → slice_0463.png
# Converted: slice_0464.jpg → slice_0464.png
# Converted: slice_0465.jpg → slice_0465.png
# Converted: slice_0466.jpg → slice_0466.png
# Converted: slice_0467.jpg → slice_0467.png
# Converted: slice_0468.jpg → slice_0468.png
# Converted: slice_0469.jpg → slice_0469.png
# Converted: slice_0470.jpg → slice_0470.png
# Converted: slice_0471.jpg → slice_0471.png
# Converted: slice_0472.jpg → slice_0472.png
# Converted: slice_0473.jpg → slice_0473.png
# Converted: slice_0474.jpg → slice_0474.png
# Converted: slice_0475.jpg → slice_0475.png
# Converted: slice_0476.jpg → slice_0476.png
# Converted: slice_0477.jpg → slice_0477.png
# Converted: slice_0478.jpg → slice_0478.png
# Converted: slice_0479.jpg → slice_0479.png
# Converted: slice_0480.jpg → slice_0480.png
# Converted: slice_0481.jpg → slice_0481.png
# Converted: slice_0482.jpg → slice_0482.png
# Converted: slice_0483.jpg → slice_0483.png
# Converted: slice_0484.jpg → slice_0484.png
# Converted: slice_0485.jpg → slice_0485.png
# Converted: slice_0486.jpg → slice_0486.png
# Converted: slice_0487.jpg → slice_0487.png
# Converted: slice_0488.jpg → slice_0488.png
# Converted: slice_0489.jpg → slice_0489.png
# Converted: slice_0490.jpg → slice_0490.png
# Converted: slice_0491.jpg → slice_0491.png
# Converted: slice_0492.jpg → slice_0492.png
# Converted: slice_0493.jpg → slice_0493.png
# Converted: slice_0494.jpg → slice_0494.png
# Converted: slice_0495.jpg → slice_0495.png
# Converted: slice_0496.jpg → slice_0496.png
# Converted: slice_0497.jpg → slice_0497.png
# Converted: slice_0498.jpg → slice_0498.png
# Converted: slice_0499.jpg → slice_0499.png
#
# ✔ JPG → PNG conversion complete.

# %%
# PART 2 — Load PNGs and resize to 300×300
# ---------------------------------------------------
png_files = sorted(png_folder.glob("*.png"))
imgs = []

for f in png_files:
    img = io.imread(f)

    # If RGB or RGBA → convert to grayscale
    if img.ndim == 3:
        img = img[..., 0]

    img = img.astype(np.float32) / 255.0
    img_r = transform.resize(img, resize_shape, anti_aliasing=True)
    imgs.append(img_r)

volume = np.stack(imgs)
print("Loaded resized volume:", volume.shape)
# Out:
# Loaded resized volume: (500, 200, 200)

# %%
# PART 3 — Apply Masking
# ---------------------------------------------------
from skimage import filters, morphology
vol = volume.copy()
mask_method = "superclean"

if mask_method == "adaptive":
    masked = np.zeros_like(vol)
    for i in range(vol.shape[0]):
        t = threshold_local(vol[i], block_size=35, offset=0.01)
        masked[i] = vol[i] * (vol[i] > t)
    print("Applied adaptive masking.")

elif mask_method == "percentile":
    base_thresh = np.percentile(vol, percentile_value)
    thresh = base_thresh * 0.63
    masked = vol * (vol < thresh)
    print("Applied percentile masking:", thresh)

elif mask_method == "manual":
    masked = vol * (vol < manual_threshold_value)
    print("Applied manual masking:", manual_threshold_value)

elif mask_method == "three":
    blur = filters.gaussian(vol, sigma=1.5)
    t = filters.threshold_li(blur)
    binary = blur < t
    cleaned = morphology.remove_small_objects(binary, min_size=150)
    cleaned = morphology.binary_closing(cleaned, morphology.disk(3))
    masked = vol * cleaned
    print("Applied three.", cleaned)

elif mask_method == "superclean":
    masked = np.zeros_like(vol)

    for i in range(vol.shape[0]):
        slice_ = vol[i]

        # Gaussian blur per slice
        blur = filters.gaussian(slice_, sigma=1.5)

        # Li threshold per slice
        t = filters.threshold_li(blur)
        binary = blur < t

        # Invert mask: True = background, False = foreground
        binary = ~binary

        # Remove small objects (remove background noise)
        cleaned = morphology.remove_small_objects(binary, min_size=150)

        # Close holes in background
        cleaned = morphology.binary_closing(cleaned, morphology.disk(3))

        # Invert again to get foreground mask
        foreground_mask = ~cleaned

        masked[i] = slice_ * foreground_mask

    print("Applied FIXED SUPER-CLEAN mask: background removed, bacteria kept.")


else:
    raise ValueError("Invalid mask_method selected.")
# Out:
# Applied FIXED SUPER-CLEAN mask: background removed, bacteria kept.

# %%
# PART 4 — Save Final Volume
# ---------------------------------------------------
np.save("volume_raw2.npy", vol.astype(np.float32))
np.save("volume_tomo_003acc.npy", masked.astype(np.float32))

print("\n✔ Saved volume_raw.npy and volume_masked.npy")
# Out:
# ✔ Saved volume_raw.npy and volume_masked.npy
